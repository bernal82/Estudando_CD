# %%
# Estudando Ciência de Dados

# Boxplot com Seaborn

# %%
# Importação das bibliotecas
import pandas as pd
import seaborn as srn

# %%
# Carregamento da base de dados
base = pd.read_csv('trees.csv')
base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
# Visualização de um boxplot

# Com a biblioteca seaborn é possível geral boxplot mais sofisticado
# 'v' vertical | 'h' horizontal

srn.boxplot(data=base.Volume, orient='v').set_title('Árvores')
# Out:
# Text(0.5, 1.0, 'Árvores')

# %%
# Visualização de vários boxplots na mesma imagem

srn.boxplot(data = base)
# Out:
# <Axes: >
